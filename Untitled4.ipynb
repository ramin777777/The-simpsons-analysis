# %% [markdown]
# # Introduction
#
# * The Simpsons is an American animated sitcom created by Matt Groening for the Fox Broadcasting Company.Developed by Groening, James L. Brooks, and Sam Simon, the series is a satirical depiction of American life, epitomized by the Simpson family, which consists of Homer, Marge, Bart, Lisa, and Maggie. Set in the fictional town of Springfield, it caricatures society, Western culture, television, and the human condition.
#
# **The family was conceived by Groening shortly before a solicitation for a series of animated shorts with producer Brooks. He created a dysfunctional family and named the characters after his own family members, substituting Bart for his own name; he thought Simpson was a funny name in that it sounded similar to "simpleton".The shorts became a part of The Tracey Ullman Show on April 19, 1987. After three seasons, the sketch was developed into a half-hour prime time show and became Fox's first series to land in the Top 30 ratings in a season (1989–1990).
#
# **Since its debut on December 17, 1989, 765 episodes of the show have been broadcast. It is the longest-running American animated series, longest-running American sitcom, and the longest-running American scripted primetime television series, both in seasons and individual episodes.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:\\Users\\ramin\\OneDrive\\Pulpit\\Simpsons\\simpsons_episodes.csv")

# Display the first few rows of the dataset
df.head()
# Out:
#    id                              title  \
# 0   0  Simpsons Roasting on an Open Fire
# 1   1                    Bart the Genius
# 2   2                    Homer's Odyssey
# 3   3      There's No Disgrace Like Home
# 4   4                   Bart the General
#
#                                          description original_air_date  \
# 0  Homer is forced to become a department store S...        1989-12-17
# 1  Bart ends up at a school for gifted children a...        1990-01-14
# 2  After losing his job, Homer contemplates endin...        1990-01-21
# 3  After being embarrassed by the rest of the fam...        1990-01-28
# 4  After being beaten up by Nelson Muntz one too ...        1990-02-04
#
#   production_code                     directed_by  \
# 0            7G08                 David Silverman
# 1            7G02                 David Silverman
# 2            7G03                      Wes Archer
# 3            7G04  Gregg Vanzo & Kent Butterworth
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to your image file
image_path = "C:\\Users\\ramin\\OneDrive\\Pulpit\\Simpsons\\Simpsons photo.jpeg"

# Load the image
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the column names in the dataframe
df.columns
# Out:
# Index(['id', 'title', 'description', 'original_air_date', 'production_code',
#        'directed_by', 'written_by', 'season', 'number_in_season',
#        'number_in_series', 'us_viewers_in_millions', 'imdb_rating',
#        'tmdb_rating', 'tmdb_vote_count'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
df = pd.read_csv("C:\\Users\\ramin\\OneDrive\\Pulpit\\Simpsons\\simpsons_episodes.csv")

# Calculate average viewership
average_viewership = df['us_viewers_in_millions'].mean()

# Find highest viewed episode
highest_viewed = df.loc[df['us_viewers_in_millions'].idxmax()]

# Find lowest viewed episode
lowest_viewed = df.loc[df['us_viewers_in_millions'].idxmin()]

# Display results
print("Average Viewership: {:.2f} million".format(average_viewership))
print("Highest Viewed Episode:")
print(highest_viewed)
print("Lowest Viewed Episode:")
print(lowest_viewed)

# Plotting
plt.figure(figsize=(10, 5))

# Plotting the viewership data
plt.subplot(1, 2, 1)
plt.bar(df['number_in_series'], df['us_viewers_in_millions'], color='skyblue')
plt.xlabel('Episode Number')
plt.ylabel('Viewership (millions)')
plt.title('Viewership per Episode')

# Plotting average viewership
plt.subplot(1, 2, 2)
plt.bar(['Average'], [average_viewership], color='orange')
plt.xlabel('Viewership')
plt.ylabel('Average Viewership (millions)')
plt.title('Average Viewership: {:.2f} million'.format(average_viewership))

plt.tight_layout()
plt.show()
# Out:
# Average Viewership: 10.38 million
# Highest Viewed Episode:
# id                                                                       13
# title                                                      Bart Gets an 'F'
# description               Mrs. Krabappel, fed up with Bart's lackadaisic...
# original_air_date                                                1990-10-11
# production_code                                                        7F03
# directed_by                                                 David Silverman
# written_by                                                   David M. Stern
# season                                                                    2
# number_in_season                                                          1
# number_in_series                                                         14
# us_viewers_in_millions                                                 33.6
# imdb_rating                                                             8.2
# ...

# %%
import matplotlib.pyplot as plt

# Convert air date to datetime
df['original_air_date'] = pd.to_datetime(df['original_air_date'])

# Plot viewership over time
plt.figure(figsize=(10, 6))
plt.plot(df['original_air_date'], df['us_viewers_in_millions'], color='blue')
plt.title('Viewership of The Simpsons Over Time')
plt.xlabel('Year')
plt.ylabel('Viewers (millions)')
plt.grid(True)
plt.show()

# %%
# Calculate episode-to-episode changes in viewership
df['viewership_change'] = df['us_viewers_in_millions'].diff()

# Plot episode-to-episode changes in viewership
plt.figure(figsize=(10, 6))
plt.plot(df['original_air_date'], df['viewership_change'], color='green')
plt.title('Episode-to-Episode Changes in Viewership of The Simpsons')
plt.xlabel('Year')
plt.ylabel('Change in Viewership (millions)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Report: Observed Changes in Viewership of The Simpsons
#
# * Introduction:
# The Simpsons, an iconic animated television show, has garnered a vast and dedicated viewership since its inception. Understanding the fluctuations in viewership over time is crucial for analyzing audience engagement and the show's impact. In this report, we delve into the observed changes in viewership of The Simpsons using data analysis and visualization techniques.
#
# **Data Analysis:**
# The analysis is based on a dataset containing information about various episodes of The Simpsons, including their original air dates and viewership in millions. Key insights were drawn from the dataset.
#
# * Average Viewership:
# The average viewership across all episodes was found to be approximately **10.38 million viewers**.
#
# Highest and Lowest Viewed Episodes:
# The analysis identified the highest and lowest viewed episodes based on viewership numbers. The episode with the highest viewership was [Bart Gets an 'F']. On the other hand, the episode with the lowest viewership was [Hostile Kirk Place].
#
# **Viewership Trends Over Time:**
#  The graph presents the viewership trend for "The Simpsons" from the early 1990s through to the year 2024.The series enjoyed its peak popularity in the early 1990s. The viewership reached the highest point, showing spikes above 30 million viewers.Following its peak, the show’s viewership displays a declining trend with significant fluctuations. While there are occasional spikes, indicating particular episodes or seasons with higher viewership, the general trajectory shows a decrease over time.In the last quarter shown, post-2020, the viewership appears to have stabilized, albeit at a lower average than in its heyday, hovering around the 5 million mark. This could be indicative of a dedicated core audience.
#
# Episode-to-Episode Changes:
# In the early [1990s], the changes in viewership between episodes were highly variable, with some episodes experiencing large gains and others large losses in viewership. Over time, the magnitude of these changes decreases. By the [2020s], the fluctuations appear more contained, with fewer extreme spikes in either direction.The graph indicates that while viewership for "The Simpsons" has seen some significant episode-to-episode swings over the years, the extent of these changes has become less pronounced in recent years, potentially indicating a more stable audience.
#
# **Conclusion**:
# The viewership data for "The Simpsons" illustrates a peak in early seasons followed by a gradual decline and eventual stabilization.Despite the fluctuations in its audience size, the show has retained a dedicated viewership into the 2020s. The sustained attention over time speaks to its lasting charm and significance in popular culture.
